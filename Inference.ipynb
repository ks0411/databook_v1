# %% [markdown]
# # Inference

# %%
from data_book import DataBook
# import sklearn as skl
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import confusion_matrix
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import classification_report
# from sklearn import svm
# from sklearn.linear_model import LogisticRegression
# print(skl.__version__)
raw_data_path = './Data-v1/JsonFiles/26-06-2022_1EY DB.csv.json' #'./Data-v1/OutputEnriched1006.xls'

# %% [markdown]
# ## Loading an Excel file as a DataBook object

# %%
dBook = DataBook()
dBook.load_file(raw_data_path)
dBook.get_source_data()
# Out:
#                         workbookName sheetName  numRow  numCol cellAddress  \
# key
# PL2!A1        26-06-2022_1EY DB.xlsx       PL2       1       1          A1
# PL2!B1        26-06-2022_1EY DB.xlsx       PL2       1       2          B1
# PL2!C1        26-06-2022_1EY DB.xlsx       PL2       1       3          C1
# PL2!D1        26-06-2022_1EY DB.xlsx       PL2       1       4          D1
# PL2!E1        26-06-2022_1EY DB.xlsx       PL2       1       5          E1
# ...                              ...       ...     ...     ...         ...
# Sheet12S!L55  26-06-2022_1EY DB.xlsx  Sheet12S      55      12         L55
# Sheet12S!M55  26-06-2022_1EY DB.xlsx  Sheet12S      55      13         M55
# Sheet12S!N55  26-06-2022_1EY DB.xlsx  Sheet12S      55      14         N55
# Sheet12S!O55  26-06-2022_1EY DB.xlsx  Sheet12S      55      15         O55
# Sheet12S!P55  26-06-2022_1EY DB.xlsx  Sheet12S      55      16         P55
#
#                                           cellValue cellFormula      cellType
# key
# PL2!A1        Section PL - Profit and Loss Analysis        None  SharedString
# PL2!B1                                         None        None      DateLong
# PL2!C1                                         None        None      DateLong
# PL2!D1                                         None        None      DateLong
# PL2!E1                                         None        None      DateLong
# ...                                             ...         ...           ...
# Sheet12S!L55                                   None        None          Text
# Sheet12S!M55                                   None        None          Text
# Sheet12S!N55                                   None        None          Text
# Sheet12S!O55                                   None        None          Text
# Sheet12S!P55                                   None        None          Text
#
# [4804 rows x 8 columns]

# %% [markdown]
# ## Add features
#
# We compute features for each cell, that is, for each cell we process its context

# %%
dBook.pre_process_data()
dBook.get_data()
# Out:
#               Label  up1_isBlank  up1_isFormula  up1_isSameType  \
# key
# PL2!G7        False        False          False           False
# PL2!M7        False        False          False           False
# PL2!G8        False        False           True            True
# PL2!M8        False        False           True            True
# PL2!C9        False        False          False            True
# ...             ...          ...            ...             ...
# PL6!G48       False        False          False            True
# Sheet8S!A28   False        False          False           False
# Sheet4S!A28   False        False          False           False
# Sheet01S!B1   False         True          False           False
# Sheet12S!A28  False        False          False           False
#
#               up1_isWeaklyFormulaConsistent  up2_isWeaklyFormulaConsistent  \
# key
# PL2!G7                                False                           True
# PL2!M7                                False                           True
# PL2!G8                                 True                          False
# PL2!M8                                False                          False
# PL2!C9                                False                           True
# ...                                     ...                            ...
# PL6!G48                                True                          False
# Sheet8S!A28                           False                           True
# Sheet4S!A28                           False                           True
# Sheet01S!B1                            True                           True
# Sheet12S!A28                          False                           True
#
#               dw1_isBlank  dw1_isFormula  dw1_isSameType  \
# key
# PL2!G7              False           True            True
# PL2!M7              False           True            True
# PL2!G8              False           True            True
# PL2!M8              False           True            True
# PL2!C9               True          False            True
# ...                   ...            ...             ...
# PL6!G48              True          False           False
# Sheet8S!A28          True          False           False
# Sheet4S!A28          True          False           False
# Sheet01S!B1         False          False           False
# Sheet12S!A28         True          False           False
#
#               dw1_isWeaklyFormulaConsistent  dw2_isWeaklyFormulaConsistent  \
# key
# PL2!G7                                 True                           True
# PL2!M7                                False                           True
# PL2!G8                                False                          False
# PL2!M8                                 True                          False
# PL2!C9                                False                           True
# ...                                     ...                            ...
# PL6!G48                                True                          False
# Sheet8S!A28                           False                           True
# Sheet4S!A28                           False                           True
# Sheet01S!B1                           False                           True
# Sheet12S!A28                          False                           True
#
#               nb1_isWeaklyFormulaConsistent  dw1_isSum
# key
# PL2!G7                                False       True
# PL2!M7                                 True      False
# PL2!G8                                False      False
# PL2!M8                                False      False
# PL2!C9                                 True      False
# ...                                     ...        ...
# PL6!G48                                True      False
# Sheet8S!A28                            True      False
# Sheet4S!A28                            True      False
# Sheet01S!B1                            True      False
# Sheet12S!A28                           True      False
#
# [574 rows x 13 columns]

# %% [markdown]
# ## Get some data to make a prediction
#
# Note that as this is test code, we are just using the same data we already used for training.

# %%
df=dBook.get_inconsistent_cells()
df
# Out:
#               up1_isBlank  up1_isFormula  up1_isSameType  \
# key
# PL2!G7              False          False           False
# PL2!M7              False          False           False
# PL2!G8              False           True            True
# PL2!M8              False           True            True
# PL2!C9              False          False            True
# ...                   ...            ...             ...
# PL6!E48             False           True            True
# Sheet8S!A28         False          False           False
# Sheet4S!A28         False          False           False
# Sheet01S!B1          True          False           False
# Sheet12S!A28        False          False           False
#
#               up1_isWeaklyFormulaConsistent  up2_isWeaklyFormulaConsistent  \
# key
# PL2!G7                                False                           True
# PL2!M7                                False                           True
# PL2!G8                                 True                          False
# PL2!M8                                False                          False
# PL2!C9                                False                           True
# ...                                     ...                            ...
# PL6!E48                               False                          False
# Sheet8S!A28                           False                           True
# Sheet4S!A28                           False                           True
# Sheet01S!B1                            True                           True
# Sheet12S!A28                          False                           True
#
#               dw1_isBlank  dw1_isFormula  dw1_isSameType  \
# key
# PL2!G7              False           True            True
# PL2!M7              False           True            True
# PL2!G8              False           True            True
# PL2!M8              False           True            True
# PL2!C9               True          False            True
# ...                   ...            ...             ...
# PL6!E48              True          False           False
# Sheet8S!A28          True          False           False
# Sheet4S!A28          True          False           False
# Sheet01S!B1         False          False           False
# Sheet12S!A28         True          False           False
#
#               dw1_isWeaklyFormulaConsistent  dw2_isWeaklyFormulaConsistent  \
# key
# PL2!G7                                 True                           True
# PL2!M7                                False                           True
# PL2!G8                                False                          False
# PL2!M8                                 True                          False
# PL2!C9                                False                           True
# ...                                     ...                            ...
# PL6!E48                               False                          False
# Sheet8S!A28                           False                           True
# Sheet4S!A28                           False                           True
# Sheet01S!B1                           False                           True
# Sheet12S!A28                          False                           True
#
#               nb1_isWeaklyFormulaConsistent  dw1_isSum
# key
# PL2!G7                                False       True
# PL2!M7                                 True      False
# PL2!G8                                False      False
# PL2!M8                                False      False
# PL2!C9                                 True      False
# ...                                     ...        ...
# PL6!E48                               False      False
# Sheet8S!A28                            True      False
# Sheet4S!A28                            True      False
# Sheet01S!B1                            True      False
# Sheet12S!A28                           True      False
#
# [277 rows x 12 columns]

# %% [markdown]
# ## Make inference

# %%
import pickle
with open('./model.pkl', 'rb') as f:
    model = pickle.load(f)
model
# Out:
# LinearSVC()

# %%
predictions = model.predict(df)

# %%
[idx for idx, pred in zip(df.index, predictions) if pred]
# Out:
# ['PL2!M7',
#  'PL2!C20',
#  'PL2!D20',
#  'PL2!G20',
#  'PL2!I20',
#  'PL2!M20',
#  'PL2!C21',
#  'PL2!D21',
#  'PL2!I21',
#  'PL2!C22',
#  'PL2!I22',
#  'PL2!E28',
#  'PL2!F28',
#  'PL2!G28',
#  'PL2!J28',
#  'PL2!K28',
#  'PL2!L28',
#  'PL2!M28',
#  'PL2!E29',
#  'PL2!F29',
#  'PL2!G29',
#  'PL2!J29',
#  'PL2!K29',
#  'PL2!L29',
#  'PL2!M29',
#  'PL3!C10',
#  'PL3!D10',
#  'PL3!C20',
#  'PL3!D20',
#  'PL4!G27',
#  'PL4!H27',
#  'PL4!G28',
#  'PL4!H28',
#  'PL4!D46',
#  'PL5!H7',
#  'PL5!G24',
#  'PL5!H24',
#  'PL5!G25',
#  'PL5!C39',
#  'PL6!C30',
#  'PL6!D30',
#  'PL6!C31',
#  'PL6!D31',
#  'PL6!E46',
#  'PL6!E47']

# %%
import json

jsonDict = {idx:str(pred) for idx, pred in zip(df.index, predictions)}
jsonString = json.dumps(jsonDict, indent=4)


fileName = f"__scored__{dBook.get_raw_data_path().stem}.json"

with open(fileName, 'w') as f:
    f.write(jsonString)
