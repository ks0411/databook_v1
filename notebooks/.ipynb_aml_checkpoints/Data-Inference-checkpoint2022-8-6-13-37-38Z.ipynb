# %% [markdown]
# # Inference

# %% [markdown]
# To run this NB, install the DataBook class wheel
# ```
# pip install <wheel-file-name.whl>
# ```

# %%
import joblib
import json
from databook.data_book import DataBook
import pickle

# %%
raw_data_path = '../Data-v1/Standard_Databook_ 06 07 2022.csv.json'

# %% [markdown]
# ## Loading an Excel file as a DataBook object

# %%
dBook = DataBook()
dBook.load_file(raw_data_path)
dBook.get_data(all_columns=True)
# Out:
#                                     workbookName sheetName  numRow  numCol  \
# key
# Cover!A1      Standard_Databook_ 06 07 2022.xlsx     Cover       1       1
# Cover!B1      Standard_Databook_ 06 07 2022.xlsx     Cover       1       2
# Cover!C1      Standard_Databook_ 06 07 2022.xlsx     Cover       1       3
# Cover!D1      Standard_Databook_ 06 07 2022.xlsx     Cover       1       4
# Cover!E1      Standard_Databook_ 06 07 2022.xlsx     Cover       1       5
# ...                                          ...       ...     ...     ...
# Sheet12S!L55  Standard_Databook_ 06 07 2022.xlsx  Sheet12S      55      12
# Sheet12S!M55  Standard_Databook_ 06 07 2022.xlsx  Sheet12S      55      13
# Sheet12S!N55  Standard_Databook_ 06 07 2022.xlsx  Sheet12S      55      14
# Sheet12S!O55  Standard_Databook_ 06 07 2022.xlsx  Sheet12S      55      15
# Sheet12S!P55  Standard_Databook_ 06 07 2022.xlsx  Sheet12S      55      16
#
#              cellAddress cellValue cellFormula  cellType
# key
# Cover!A1              A1      None        None   General
# Cover!B1              B1      None        None      Time
# Cover!C1              C1      None        None      Time
# Cover!D1              D1      None        None      Time
# Cover!E1              E1      None        None      Time
# ...                  ...       ...         ...       ...
# Sheet12S!L55         L55      None        None  Currency
# Sheet12S!M55         M55      None        None  Currency
# Sheet12S!N55         N55      None        None  Currency
# Sheet12S!O55         O55      None        None  Currency
# Sheet12S!P55         P55      None        None  Currency
#
# [32612 rows x 8 columns]

# %% [markdown]
# ## Add features for inference
#
# We compute features for each cell, that is, for each cell we process its context

# %%
dBook.pre_process_data(for_training=False)
dBook.get_data()
# Out:
#                         sheetName cellAddress  up1_isBlank  up1_isFormula  \
# key
# Cover!AZ1                   Cover         AZ1         True          False
# Lead PL!O1                Lead PL          O1         True          False
# Lead PL!C7                Lead PL          C7        False          False
# Lead PL!D7                Lead PL          D7        False          False
# Lead PL!E7                Lead PL          E7        False          False
# ...                           ...         ...          ...            ...
# ScratchPad_TB!H152  ScratchPad_TB        H152         True          False
# Sheet8S!A28               Sheet8S         A28        False          False
# Sheet4S!A28               Sheet4S         A28        False          False
# Sheet01S!B1              Sheet01S          B1         True          False
# Sheet12S!A28             Sheet12S         A28        False          False
#
#                     up1_isSameType  up1_isWeaklyFormulaConsistent  \
# key
# Cover!AZ1                    False                           True
# Lead PL!O1                   False                           True
# Lead PL!C7                   False                          False
# Lead PL!D7                   False                          False
# Lead PL!E7                   False                          False
# ...                            ...                            ...
# ScratchPad_TB!H152           False                          False
# Sheet8S!A28                  False                          False
# Sheet4S!A28                  False                          False
# Sheet01S!B1                  False                           True
# Sheet12S!A28                 False                          False
#
#                     up2_isWeaklyFormulaConsistent  dw1_isBlank  dw1_isFormula  \
# key
# Cover!AZ1                                    True        False          False
# Lead PL!O1                                   True         True          False
# Lead PL!C7                                   True        False           True
# Lead PL!D7                                   True        False           True
# Lead PL!E7                                   True        False           True
# ...                                           ...          ...            ...
# ScratchPad_TB!H152                           True         True          False
# Sheet8S!A28                                  True         True          False
# Sheet4S!A28                                  True         True          False
# Sheet01S!B1                                  True        False          False
# Sheet12S!A28                                 True         True          False
#
#                     dw1_isSameType  dw1_isWeaklyFormulaConsistent  \
# key
# Cover!AZ1                    False                          False
# Lead PL!O1                   False                           True
# Lead PL!C7                    True                           True
# Lead PL!D7                    True                           True
# Lead PL!E7                    True                           True
# ...                            ...                            ...
# ScratchPad_TB!H152           False                          False
# Sheet8S!A28                  False                          False
# Sheet4S!A28                  False                          False
# Sheet01S!B1                  False                          False
# Sheet12S!A28                 False                          False
#
#                     dw2_isWeaklyFormulaConsistent  \
# key
# Cover!AZ1                                    True
# Lead PL!O1                                   True
# Lead PL!C7                                   True
# Lead PL!D7                                   True
# Lead PL!E7                                   True
# ...                                           ...
# ScratchPad_TB!H152                           True
# Sheet8S!A28                                  True
# Sheet4S!A28                                  True
# Sheet01S!B1                                  True
# Sheet12S!A28                                 True
#
#                     nb1_isWeaklyFormulaConsistent  dw1_isSum
# key
# Cover!AZ1                                    True      False
# Lead PL!O1                                   True      False
# Lead PL!C7                                  False      False
# Lead PL!D7                                  False      False
# Lead PL!E7                                  False      False
# ...                                           ...        ...
# ScratchPad_TB!H152                           True      False
# Sheet8S!A28                                  True      False
# Sheet4S!A28                                  True      False
# Sheet01S!B1                                  True      False
# Sheet12S!A28                                 True      False
#
# [3268 rows x 14 columns]

# %% [markdown]
# ## Load a model

# %%
with open ('./model.pkl', 'br') as f:
    model = pickle.load(f)
model
# Out:
# LogisticRegression(multi_class='ovr', random_state=0)

# %% [markdown]
# ## Get some data to make a prediction
#
# Note that this is sample code, and we felt free to use the same data we already used for training! On a real situation this wouldn't happen.

# %% [markdown]
# #### Score a single cell

# %% [markdown]
# *G16* in *PL8-Other income exp* is wrongly evaluated as non-error

# %%
df_for_inference_cell=dBook.get_inconsistent_cells(sheet_filter='PL8-Other income exp', cell_filter='G16')
df_for_inference_cell
# Out:
#                           up1_isBlank  up1_isFormula  up1_isSameType  \
# key
# PL8-Other income exp!G16        False           True            True
#
#                           up1_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!G16                          False
#
#                           up2_isWeaklyFormulaConsistent  dw1_isBlank  \
# key
# PL8-Other income exp!G16                           True        False
#
#                           dw1_isFormula  dw1_isSameType  \
# key
# PL8-Other income exp!G16           True            True
#
#                           dw1_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!G16                          False
#
#                           dw2_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!G16                           True
#
#                           nb1_isWeaklyFormulaConsistent  dw1_isSum
# key
# PL8-Other income exp!G16                           True      False

# %%
model.predict(df_for_inference_cell)
# Out:
# array([False])

# %% [markdown]
# #### Score an entire sheet

# %%
df_for_inference_sheet=dBook.get_inconsistent_cells(sheet_filter='PL8-Other income exp')
df_for_inference_sheet
# Out:
#                           up1_isBlank  up1_isFormula  up1_isSameType  \
# key
# PL8-Other income exp!B7         False          False           False
# PL8-Other income exp!C7         False          False           False
# PL8-Other income exp!D7         False          False           False
# PL8-Other income exp!F7         False          False           False
# PL8-Other income exp!G7         False          False           False
# PL8-Other income exp!H7         False          False           False
# PL8-Other income exp!I7         False          False           False
# PL8-Other income exp!F8         False           True            True
# PL8-Other income exp!G8         False           True            True
# PL8-Other income exp!H8         False           True            True
# PL8-Other income exp!I8         False           True            True
# PL8-Other income exp!F9         False           True            True
# PL8-Other income exp!G9         False           True            True
# PL8-Other income exp!I9         False           True            True
# PL8-Other income exp!H10        False           True            True
# PL8-Other income exp!H11        False           True            True
# PL8-Other income exp!H12        False           True            True
# PL8-Other income exp!H13        False           True            True
# PL8-Other income exp!F15        False           True            True
# PL8-Other income exp!G15        False           True            True
# PL8-Other income exp!B16        False           True            True
# PL8-Other income exp!C16        False           True            True
# PL8-Other income exp!D16        False           True            True
# PL8-Other income exp!F16        False           True            True
# PL8-Other income exp!G16        False           True            True
# PL8-Other income exp!B17        False           True            True
# PL8-Other income exp!C17        False           True            True
# PL8-Other income exp!D17        False           True            True
# PL8-Other income exp!F17        False           True            True
# PL8-Other income exp!G17        False           True            True
# PL8-Other income exp!H17        False           True            True
# PL8-Other income exp!I17        False           True            True
# PL8-Other income exp!B18        False           True            True
# PL8-Other income exp!C18        False           True            True
# PL8-Other income exp!D18        False           True            True
# PL8-Other income exp!H18        False           True            True
# PL8-Other income exp!I18        False           True            True
# PL8-Other income exp!B19        False           True            True
# PL8-Other income exp!C19        False           True            True
# PL8-Other income exp!D19        False           True            True
# PL8-Other income exp!H19        False           True            True
# PL8-Other income exp!I19        False           True            True
# PL8-Other income exp!B20        False           True            True
# PL8-Other income exp!C20        False           True            True
# PL8-Other income exp!D20        False           True            True
# PL8-Other income exp!H20        False           True            True
# PL8-Other income exp!B21        False           True            True
# PL8-Other income exp!C21        False           True            True
# PL8-Other income exp!D21        False           True            True
# PL8-Other income exp!A23        False          False           False
# PL8-Other income exp!B30         True          False           False
# PL8-Other income exp!C30         True          False           False
# PL8-Other income exp!D30         True          False           False
# PL8-Other income exp!B31        False           True            True
# PL8-Other income exp!C31        False           True            True
# PL8-Other income exp!D31        False           True            True
#
#                           up1_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!B7                           False
# PL8-Other income exp!C7                           False
# PL8-Other income exp!D7                           False
# PL8-Other income exp!F7                           False
# PL8-Other income exp!G7                           False
# PL8-Other income exp!H7                           False
# PL8-Other income exp!I7                           False
# PL8-Other income exp!F8                            True
# PL8-Other income exp!G8                            True
# PL8-Other income exp!H8                           False
# PL8-Other income exp!I8                            True
# PL8-Other income exp!F9                           False
# PL8-Other income exp!G9                           False
# PL8-Other income exp!I9                           False
# PL8-Other income exp!H10                           True
# PL8-Other income exp!H11                          False
# PL8-Other income exp!H12                           True
# PL8-Other income exp!H13                          False
# PL8-Other income exp!F15                           True
# PL8-Other income exp!G15                           True
# PL8-Other income exp!B16                           True
# PL8-Other income exp!C16                           True
# PL8-Other income exp!D16                           True
# PL8-Other income exp!F16                          False
# PL8-Other income exp!G16                          False
# PL8-Other income exp!B17                          False
# PL8-Other income exp!C17                          False
# PL8-Other income exp!D17                          False
# PL8-Other income exp!F17                          False
# PL8-Other income exp!G17                          False
# PL8-Other income exp!H17                           True
# PL8-Other income exp!I17                           True
# PL8-Other income exp!B18                          False
# PL8-Other income exp!C18                          False
# PL8-Other income exp!D18                          False
# PL8-Other income exp!H18                          False
# PL8-Other income exp!I18                          False
# PL8-Other income exp!B19                           True
# PL8-Other income exp!C19                           True
# PL8-Other income exp!D19                           True
# PL8-Other income exp!H19                          False
# PL8-Other income exp!I19                          False
# PL8-Other income exp!B20                          False
# PL8-Other income exp!C20                          False
# PL8-Other income exp!D20                          False
# PL8-Other income exp!H20                          False
# PL8-Other income exp!B21                          False
# PL8-Other income exp!C21                          False
# PL8-Other income exp!D21                          False
# PL8-Other income exp!A23                          False
# PL8-Other income exp!B30                          False
# PL8-Other income exp!C30                          False
# PL8-Other income exp!D30                          False
# PL8-Other income exp!B31                          False
# PL8-Other income exp!C31                          False
# PL8-Other income exp!D31                          False
#
#                           up2_isWeaklyFormulaConsistent  dw1_isBlank  \
# key
# PL8-Other income exp!B7                            True        False
# PL8-Other income exp!C7                            True        False
# PL8-Other income exp!D7                            True        False
# PL8-Other income exp!F7                            True        False
# PL8-Other income exp!G7                            True        False
# PL8-Other income exp!H7                            True        False
# PL8-Other income exp!I7                            True        False
# PL8-Other income exp!F8                           False        False
# PL8-Other income exp!G8                           False        False
# PL8-Other income exp!H8                           False        False
# PL8-Other income exp!I8                           False        False
# PL8-Other income exp!F9                            True        False
# PL8-Other income exp!G9                            True        False
# PL8-Other income exp!I9                            True        False
# PL8-Other income exp!H10                           True        False
# PL8-Other income exp!H11                           True        False
# PL8-Other income exp!H12                          False        False
# PL8-Other income exp!H13                           True        False
# PL8-Other income exp!F15                           True        False
# PL8-Other income exp!G15                           True        False
# PL8-Other income exp!B16                           True        False
# PL8-Other income exp!C16                           True        False
# PL8-Other income exp!D16                           True        False
# PL8-Other income exp!F16                           True        False
# PL8-Other income exp!G16                           True        False
# PL8-Other income exp!B17                           True        False
# PL8-Other income exp!C17                           True        False
# PL8-Other income exp!D17                           True        False
# PL8-Other income exp!F17                          False        False
# PL8-Other income exp!G17                          False        False
# PL8-Other income exp!H17                           True        False
# PL8-Other income exp!I17                           True        False
# PL8-Other income exp!B18                          False        False
# PL8-Other income exp!C18                          False        False
# PL8-Other income exp!D18                          False        False
# PL8-Other income exp!H18                           True        False
# PL8-Other income exp!I18                           True        False
# PL8-Other income exp!B19                          False        False
# PL8-Other income exp!C19                          False        False
# PL8-Other income exp!D19                          False        False
# PL8-Other income exp!H19                          False        False
# PL8-Other income exp!I19                          False        False
# PL8-Other income exp!B20                           True        False
# PL8-Other income exp!C20                           True        False
# PL8-Other income exp!D20                           True        False
# PL8-Other income exp!H20                          False         True
# PL8-Other income exp!B21                          False         True
# PL8-Other income exp!C21                          False         True
# PL8-Other income exp!D21                          False         True
# PL8-Other income exp!A23                           True         True
# PL8-Other income exp!B30                           True        False
# PL8-Other income exp!C30                           True        False
# PL8-Other income exp!D30                           True        False
# PL8-Other income exp!B31                          False         True
# PL8-Other income exp!C31                          False         True
# PL8-Other income exp!D31                          False         True
#
#                           dw1_isFormula  dw1_isSameType  \
# key
# PL8-Other income exp!B7            True            True
# PL8-Other income exp!C7            True            True
# PL8-Other income exp!D7            True            True
# PL8-Other income exp!F7            True            True
# PL8-Other income exp!G7            True            True
# PL8-Other income exp!H7            True            True
# PL8-Other income exp!I7            True            True
# PL8-Other income exp!F8            True            True
# PL8-Other income exp!G8            True            True
# PL8-Other income exp!H8            True            True
# PL8-Other income exp!I8            True            True
# PL8-Other income exp!F9            True            True
# PL8-Other income exp!G9            True            True
# PL8-Other income exp!I9            True            True
# PL8-Other income exp!H10           True            True
# PL8-Other income exp!H11           True            True
# PL8-Other income exp!H12           True            True
# PL8-Other income exp!H13           True            True
# PL8-Other income exp!F15           True            True
# PL8-Other income exp!G15           True            True
# PL8-Other income exp!B16           True            True
# PL8-Other income exp!C16           True            True
# PL8-Other income exp!D16           True            True
# PL8-Other income exp!F16           True            True
# PL8-Other income exp!G16           True            True
# PL8-Other income exp!B17           True            True
# PL8-Other income exp!C17           True            True
# PL8-Other income exp!D17           True            True
# PL8-Other income exp!F17           True            True
# PL8-Other income exp!G17           True            True
# PL8-Other income exp!H17           True            True
# PL8-Other income exp!I17           True            True
# PL8-Other income exp!B18           True            True
# PL8-Other income exp!C18           True            True
# PL8-Other income exp!D18           True            True
# PL8-Other income exp!H18           True            True
# PL8-Other income exp!I18           True            True
# PL8-Other income exp!B19           True            True
# PL8-Other income exp!C19           True            True
# PL8-Other income exp!D19           True            True
# PL8-Other income exp!H19           True            True
# PL8-Other income exp!I19           True            True
# PL8-Other income exp!B20           True            True
# PL8-Other income exp!C20           True            True
# PL8-Other income exp!D20           True            True
# PL8-Other income exp!H20          False            True
# PL8-Other income exp!B21          False            True
# PL8-Other income exp!C21          False            True
# PL8-Other income exp!D21          False            True
# PL8-Other income exp!A23          False           False
# PL8-Other income exp!B30           True            True
# PL8-Other income exp!C30           True            True
# PL8-Other income exp!D30           True            True
# PL8-Other income exp!B31          False           False
# PL8-Other income exp!C31          False           False
# PL8-Other income exp!D31          False           False
#
#                           dw1_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!B7                            True
# PL8-Other income exp!C7                            True
# PL8-Other income exp!D7                            True
# PL8-Other income exp!F7                            True
# PL8-Other income exp!G7                            True
# PL8-Other income exp!H7                           False
# PL8-Other income exp!I7                            True
# PL8-Other income exp!F8                           False
# PL8-Other income exp!G8                           False
# PL8-Other income exp!H8                            True
# PL8-Other income exp!I8                           False
# PL8-Other income exp!F9                            True
# PL8-Other income exp!G9                            True
# PL8-Other income exp!I9                            True
# PL8-Other income exp!H10                          False
# PL8-Other income exp!H11                           True
# PL8-Other income exp!H12                          False
# PL8-Other income exp!H13                           True
# PL8-Other income exp!F15                          False
# PL8-Other income exp!G15                          False
# PL8-Other income exp!B16                          False
# PL8-Other income exp!C16                          False
# PL8-Other income exp!D16                          False
# PL8-Other income exp!F16                          False
# PL8-Other income exp!G16                          False
# PL8-Other income exp!B17                          False
# PL8-Other income exp!C17                          False
# PL8-Other income exp!D17                          False
# PL8-Other income exp!F17                           True
# PL8-Other income exp!G17                           True
# PL8-Other income exp!H17                          False
# PL8-Other income exp!I17                          False
# PL8-Other income exp!B18                           True
# PL8-Other income exp!C18                           True
# PL8-Other income exp!D18                           True
# PL8-Other income exp!H18                          False
# PL8-Other income exp!I18                          False
# PL8-Other income exp!B19                          False
# PL8-Other income exp!C19                          False
# PL8-Other income exp!D19                          False
# PL8-Other income exp!H19                          False
# PL8-Other income exp!I19                           True
# PL8-Other income exp!B20                          False
# PL8-Other income exp!C20                          False
# PL8-Other income exp!D20                          False
# PL8-Other income exp!H20                          False
# PL8-Other income exp!B21                          False
# PL8-Other income exp!C21                          False
# PL8-Other income exp!D21                          False
# PL8-Other income exp!A23                          False
# PL8-Other income exp!B30                          False
# PL8-Other income exp!C30                          False
# PL8-Other income exp!D30                          False
# PL8-Other income exp!B31                          False
# PL8-Other income exp!C31                          False
# PL8-Other income exp!D31                           True
#
#                           dw2_isWeaklyFormulaConsistent  \
# key
# PL8-Other income exp!B7                            True
# PL8-Other income exp!C7                            True
# PL8-Other income exp!D7                            True
# PL8-Other income exp!F7                            True
# PL8-Other income exp!G7                            True
# PL8-Other income exp!H7                            True
# PL8-Other income exp!I7                            True
# PL8-Other income exp!F8                           False
# PL8-Other income exp!G8                           False
# PL8-Other income exp!H8                           False
# PL8-Other income exp!I8                           False
# PL8-Other income exp!F9                            True
# PL8-Other income exp!G9                            True
# PL8-Other income exp!I9                            True
# PL8-Other income exp!H10                           True
# PL8-Other income exp!H11                           True
# PL8-Other income exp!H12                          False
# PL8-Other income exp!H13                           True
# PL8-Other income exp!F15                           True
# PL8-Other income exp!G15                           True
# PL8-Other income exp!B16                           True
# PL8-Other income exp!C16                           True
# PL8-Other income exp!D16                           True
# PL8-Other income exp!F16                           True
# PL8-Other income exp!G16                           True
# PL8-Other income exp!B17                           True
# PL8-Other income exp!C17                           True
# PL8-Other income exp!D17                           True
# PL8-Other income exp!F17                          False
# PL8-Other income exp!G17                          False
# PL8-Other income exp!H17                           True
# PL8-Other income exp!I17                           True
# PL8-Other income exp!B18                          False
# PL8-Other income exp!C18                          False
# PL8-Other income exp!D18                          False
# PL8-Other income exp!H18                           True
# PL8-Other income exp!I18                           True
# PL8-Other income exp!B19                          False
# PL8-Other income exp!C19                          False
# PL8-Other income exp!D19                          False
# PL8-Other income exp!H19                          False
# PL8-Other income exp!I19                          False
# PL8-Other income exp!B20                           True
# PL8-Other income exp!C20                           True
# PL8-Other income exp!D20                           True
# PL8-Other income exp!H20                          False
# PL8-Other income exp!B21                          False
# PL8-Other income exp!C21                          False
# PL8-Other income exp!D21                          False
# PL8-Other income exp!A23                           True
# PL8-Other income exp!B30                           True
# PL8-Other income exp!C30                           True
# PL8-Other income exp!D30                           True
# PL8-Other income exp!B31                          False
# PL8-Other income exp!C31                          False
# PL8-Other income exp!D31                          False
#
#                           nb1_isWeaklyFormulaConsistent  dw1_isSum
# key
# PL8-Other income exp!B7                           False      False
# PL8-Other income exp!C7                           False      False
# PL8-Other income exp!D7                           False      False
# PL8-Other income exp!F7                           False      False
# PL8-Other income exp!G7                           False      False
# PL8-Other income exp!H7                            True      False
# PL8-Other income exp!I7                           False      False
# PL8-Other income exp!F8                           False      False
# PL8-Other income exp!G8                           False      False
# PL8-Other income exp!H8                           False      False
# PL8-Other income exp!I8                           False      False
# PL8-Other income exp!F9                           False      False
# PL8-Other income exp!G9                           False      False
# PL8-Other income exp!I9                           False      False
# PL8-Other income exp!H10                          False      False
# PL8-Other income exp!H11                          False      False
# PL8-Other income exp!H12                          False      False
# PL8-Other income exp!H13                          False      False
# PL8-Other income exp!F15                          False      False
# PL8-Other income exp!G15                          False      False
# PL8-Other income exp!B16                          False       True
# PL8-Other income exp!C16                          False       True
# PL8-Other income exp!D16                          False       True
# PL8-Other income exp!F16                           True      False
# PL8-Other income exp!G16                           True      False
# PL8-Other income exp!B17                          False      False
# PL8-Other income exp!C17                          False      False
# PL8-Other income exp!D17                          False      False
# PL8-Other income exp!F17                          False      False
# PL8-Other income exp!G17                          False      False
# PL8-Other income exp!H17                          False      False
# PL8-Other income exp!I17                          False      False
# PL8-Other income exp!B18                          False      False
# PL8-Other income exp!C18                          False      False
# PL8-Other income exp!D18                          False      False
# PL8-Other income exp!H18                           True      False
# PL8-Other income exp!I18                           True      False
# PL8-Other income exp!B19                          False       True
# PL8-Other income exp!C19                          False       True
# PL8-Other income exp!D19                          False      False
# PL8-Other income exp!H19                           True      False
# PL8-Other income exp!I19                          False      False
# PL8-Other income exp!B20                          False      False
# PL8-Other income exp!C20                          False      False
# PL8-Other income exp!D20                          False      False
# PL8-Other income exp!H20                           True      False
# PL8-Other income exp!B21                          False      False
# PL8-Other income exp!C21                          False      False
# PL8-Other income exp!D21                           True      False
# PL8-Other income exp!A23                           True      False
# PL8-Other income exp!B30                          False      False
# PL8-Other income exp!C30                          False      False
# PL8-Other income exp!D30                           True      False
# PL8-Other income exp!B31                          False      False
# PL8-Other income exp!C31                          False      False
# PL8-Other income exp!D31                          False      False

# %% [markdown]
# Cells that are evaluated as errors

# %%
results = zip(df_for_inference_sheet.index.to_list(), model.predict(df_for_inference_sheet))
[cell for cell, prediction in results if prediction]
# Out:
# ['PL8-Other income exp!B17',
#  'PL8-Other income exp!C17',
#  'PL8-Other income exp!D17',
#  'PL8-Other income exp!B20',
#  'PL8-Other income exp!C20',
#  'PL8-Other income exp!D20']

# %% [markdown]
# #### Scoring an entire workbook

# %%
df_for_inference=dBook.get_inconsistent_cells()
results = zip(df_for_inference.index.to_list(), model.predict(df_for_inference))
[cell for cell, prediction in results if prediction]
# Out:
# ['Lead CF!C9',
#  'Lead CF!D9',
#  'Lead CF!C14',
#  'Lead CF!D14',
#  'Lead CF!C15',
#  'Lead CF!D15',
#  'Lead CF!C16',
#  'Lead CF!D16',
#  'Lead CF!C17',
#  'Lead CF!D17',
#  'Lead CF!C20',
#  'Lead CF!D20',
#  'Lead CF!C21',
#  'Lead CF!D21',
#  'Lead CF!C22',
#  'Lead CF!D22',
#  'Lead CF!C23',
#  'Lead CF!D23',
#  'Lead CF!C24',
#  'Lead CF!D24',
#  'Lead BS!C18',
#  'Lead BS!C28',
#  'Lead BS!D28',
#  'Lead BS!E28',
#  'Lead BS!C29',
#  'R1!G12',
#  'R1!G19',
#  'R2!D9',
#  'R2!D10',
#  'R2!D11',
#  'R2!D14',
#  'R2!D15',
#  'R2!D16',
#  'R2!D17',
#  'R2!D18',
#  'R2!D20',
#  'R2!D21',
#  'R2!D22',
#  'R3!C9',
#  'R3!D9',
#  'R3!E9',
#  'R3!G9',
#  'R3!I9',
#  'R3!J9',
#  'R3!K9',
#  'R3!M9',
#  'R3!O9',
#  'R3!P9',
#  'R3!Q9',
#  'R3!S9',
#  'R3!G22',
#  'R3!M22',
#  'R3!S22',
#  'R3!G24',
#  'R3!M24',
#  'R3!S24',
#  'R4!F9',
#  'R4!N9',
#  'R4!R9',
#  'R4!T9',
#  'R4!F10',
#  'R4!N10',
#  'R4!R10',
#  'R4!T10',
#  'R4!N11',
#  'R4!T11',
#  'R4!N14',
#  'R4!T14',
#  'R4!N15',
#  'R4!T15',
#  'R4!N16',
#  'R4!T16',
#  'R4!N17',
#  'R4!T17',
#  'R4!C18',
#  'R4!D18',
#  'R4!F18',
#  'R4!G18',
#  'R4!M18',
#  'R4!N18',
#  'R4!R18',
#  'R4!S18',
#  'R4!T18',
#  'R4!C19',
#  'R4!D19',
#  'R4!E19',
#  'R4!G19',
#  'R4!I19',
#  'R4!J19',
#  'R4!K19',
#  'R4!M19',
#  'R4!O19',
#  'R4!P19',
#  'R4!Q19',
#  'R4!S19',
#  'R4!C20',
#  'R4!D20',
#  'R4!E20',
#  'R4!G20',
#  'R4!I20',
#  'R4!J20',
#  'R4!K20',
#  'R4!M20',
#  'R4!N20',
#  'R4!O20',
#  'R4!P20',
#  'R4!Q20',
#  'R4!S20',
#  'R4!T20',
#  'R4!C21',
#  'R4!D21',
#  'R4!E21',
#  'R4!G21',
#  'R4!I21',
#  'R4!J21',
#  'R4!K21',
#  'R4!M21',
#  'R4!N21',
#  'R4!O21',
#  'R4!P21',
#  'R4!Q21',
#  'R4!S21',
#  'R4!T21',
#  'R4!C22',
#  'R4!D22',
#  'R4!E22',
#  'R4!G22',
#  'R4!I22',
#  'R4!J22',
#  'R4!K22',
#  'R4!M22',
#  'R4!N22',
#  'R4!O22',
#  'R4!P22',
#  'R4!Q22',
#  'R4!S22',
#  'R4!T22',
#  'R4!C28',
#  'R4!D28',
#  'R4!C29',
#  'R4!D29',
#  'PL3-COGS!B10',
#  'PL3-COGS!C10',
#  'PL3-COGS!D10',
#  'PL4-Personnel cost!B16',
#  'PL4-Personnel cost!C16',
#  'PL5-Service cost!B10',
#  'PL5-Service cost!C10',
#  'PL5-Service cost!D10',
#  'PL5-Service cost!B12',
#  'PL5-Service cost!C12',
#  'PL5-Service cost!D12',
#  'PL6-Agents cost!B10',
#  'PL6-Agents cost!C10',
#  'PL6-Agents cost!D10',
#  'PL7-Rent & Lease!B9',
#  'PL7-Rent & Lease!C9',
#  'PL7-Rent & Lease!D9',
#  'PL7-Rent & Lease!B11',
#  'PL7-Rent & Lease!C11',
#  'PL7-Rent & Lease!D11',
#  'PL8-Other income exp!B17',
#  'PL8-Other income exp!C17',
#  'PL8-Other income exp!D17',
#  'PL8-Other income exp!B20',
#  'PL8-Other income exp!C20',
#  'PL8-Other income exp!D20',
#  'PL9-G&A!B16',
#  'PL9-G&A!C16',
#  'PL9-G&A!D16',
#  'PL10-churn analysis!C7',
#  'PL10-churn analysis!B8',
#  'PL10-churn analysis!C8',
#  'PL10-churn analysis!B9',
#  'PL10-churn analysis!C9',
#  'PL10-churn analysis!B17',
#  'PL10-churn analysis!C17',
#  'PL10-churn analysis!B18',
#  'PL10-churn analysis!C18',
#  'PL10-churn analysis!B19',
#  'PL10-churn analysis!C19',
#  'PL11-Churn Bridge working!D8',
#  'PL11-Churn Bridge working!C12',
#  'PL11-Churn Bridge working!D12',
#  'BS2- FA rollforward!C13',
#  'BS2- FA rollforward!D13',
#  'BS3-Inventory!B9',
#  'BS3-Inventory!C9',
#  'BS3-Inventory!D9',
#  'BS4-Trade receivables!B13',
#  'BS4-Trade receivables!C13',
#  'BS4-Trade receivables!D13',
#  'BS4-Trade receivables!B15',
#  'BS4-Trade receivables!C15',
#  'BS4-Trade receivables!D15',
#  'BS5-TR ageing!C7',
#  'BS5-TR ageing!D7',
#  'BS5-TR ageing!E7',
#  'BS5-TR ageing!C8',
#  'BS5-TR ageing!D8',
#  'BS5-TR ageing!E8',
#  'BS5-TR ageing!C9',
#  'BS5-TR ageing!D9',
#  'BS5-TR ageing!E9',
#  'BS5-TR ageing!C10',
#  'BS5-TR ageing!D10',
#  'BS5-TR ageing!E10',
#  'BS5-TR ageing!C11',
#  'BS5-TR ageing!D11',
#  'BS5-TR ageing!E11',
#  'BS5-TR ageing!C12',
#  'BS5-TR ageing!D12',
#  'BS5-TR ageing!E12',
#  'BS5-TR ageing!C13',
#  'BS5-TR ageing!D13',
#  'BS5-TR ageing!C14',
#  'BS5-TR ageing!D14',
#  'BS5-TR ageing!C15',
#  'BS5-TR ageing!D15',
#  'BS5-TR ageing!E15',
#  'BS6-Trade payable!B11',
#  'BS6-Trade payable!C11',
#  'BS6-Trade payable!D11',
#  'BS6-Trade payable!D12',
#  'BS6-Trade payable!B13',
#  'BS6-Trade payable!C13',
#  'BS6-Trade payable!D13',
#  'BS8-TP ageing!C7',
#  'BS8-TP ageing!D7',
#  'BS8-TP ageing!E7',
#  'BS8-TP ageing!C8',
#  'BS8-TP ageing!D8',
#  'BS8-TP ageing!E8',
#  'BS8-TP ageing!C9',
#  'BS8-TP ageing!D9',
#  'BS8-TP ageing!E9',
#  'BS8-TP ageing!C10',
#  'BS8-TP ageing!D10',
#  'BS8-TP ageing!E10',
#  'BS8-TP ageing!C11',
#  'BS8-TP ageing!D11',
#  'BS8-TP ageing!E11',
#  'BS8-TP ageing!C12',
#  'BS8-TP ageing!D12',
#  'BS8-TP ageing!E12',
#  'BS8-TP ageing!C13',
#  'BS8-TP ageing!D13',
#  'BS8-TP ageing!C14',
#  'BS8-TP ageing!D14',
#  'BS8-TP ageing!C15',
#  'BS8-TP ageing!D15',
#  'BS8-TP ageing!E15',
#  'BS8-TP ageing!C16',
#  'BS8-TP ageing!D16',
#  'BS8-TP ageing!E16',
#  'BS12-Net equity!B11',
#  'BS12-Net equity!C11',
#  'BS12-Net equity!D11',
#  'BS12-Net equity!D12',
#  'BS12-Net equity!B13',
#  'BS12-Net equity!C13',
#  'BS12-Net equity!D13',
#  'ScratchPad_FA RollF working!D12',
#  'ScratchPad_FA RollF working!H12',
#  'ScratchPad_TB!I4']
